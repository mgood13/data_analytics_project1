# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
filename = './Data/Teams.csv'
teams_df = pd.read_csv(filename)
teams_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP    FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ... NaN  0.83
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ... NaN  0.82
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ... NaN  0.81
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ... NaN  0.80
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ... NaN  0.83
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
len(teams_df['name'].unique())
# Out:
# 139

# %%
teams_df['Cumulative Wins'] = teams_df.groupby(['name'])['W'].cumsum()
teams_df.sort_values(['name','yearID'])
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...     FP  \
# 124     1884   UA    ALT      ALT   NaN    10   25    NaN   6  19  ...  0.860
# 2237    1997   AL    ANA      ANA     W     2  162   82.0  84  78  ...  0.980
# 2265    1998   AL    ANA      ANA     W     2  162   81.0  85  77  ...  0.980
# 2295    1999   AL    ANA      ANA     W     4  162   81.0  70  92  ...  0.980
# 2325    2000   AL    ANA      ANA     W     3  162   81.0  82  80  ...  0.978
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ..  ..  ...    ...
# 278     1891   AA    WS9      WAS   NaN     9  139    NaN  44  91  ...  0.900
# 154     1884   UA    WIL      WIL   NaN    12   18    NaN   2  16  ...  0.850
# 85      1880   NL    WOR      WOR   NaN     5   85    NaN  40  43  ...  0.900
# 93      1881   NL    WOR      WOR   NaN     8   83    NaN  32  50  ...  0.900
# 107     1882   NL    WOR      WOR   NaN     8   84    NaN  18  66  ...  0.870
#
# ...

# %%
for index,row in teams_df.iterrows():
    plt.plot(index,['Cumulative Wins'])

# %%
team_sum = team_sum.sort_values('W', ascending = False)
team_sum.head(5)
# Out:
#                      yearID  Rank      G   Ghome     W     L      R      AB  \
# name
# Pittsburgh Pirates   244125   510  19366  8999.0  9800  9446  86183  663407
# Cincinnati Reds      243666   534  18946  8562.0  9427  9390  83151  645455
# St. Louis Cardinals  227070   405  18120  9018.0  9390  8624  80463  620004
# New York Yankees     202292   256  16138  8069.0  9266  6811  79711  552383
# Detroit Tigers       225170   430  17984  8998.0  9085  8806  83219  613733
#
#                           H     2B  ...      HA    HRA    BBA    SOA      E  \
# name                                ...
# Pittsburgh Pirates   176477  28760  ...  174044  11234  57895  85550  22525
# Cincinnati Reds      168649  28087  ...  170124  11454  57214  84733  22927
# St. Louis Cardinals  165557  28294  ...  161194  11312  55521  84533  19045
# New York Yankees     148042  24815  ...  140208  11384  52562  81283  14139
# Detroit Tigers       163093  27364  ...  162117  12885  60170  84612  18665
#
# ...

# %%
team_sum = team_sum.reset_index()
# Out:
#     index                                               name   yearID   Rank  \
# 0       0                                 Pittsburgh Pirates   244125    510
# 1       1                  Pittsburgh PiratesCincinnati Reds   487791   1044
# 2       3  Pittsburgh PiratesCincinnati RedsSt. Louis Car...   714861   1449
# 3       6  Pittsburgh PiratesCincinnati RedsSt. Louis Car...   917153   1705
# 4      10  Pittsburgh PiratesCincinnati RedsSt. Louis Car...  1142323   2135
# ..    ...                                                ...      ...    ...
# 134  9045  Pittsburgh PiratesCincinnati RedsSt. Louis Car...  5476371  11476
# 135  9180  Pittsburgh PiratesCincinnati RedsSt. Louis Car...  5478246  11487
# 136  9316  Pittsburgh PiratesCincinnati RedsSt. Louis Car...  5480130  11499
# 137  9453  Pittsburgh PiratesCincinnati RedsSt. Louis Car...  5482005  11512
# 138  9591  Pittsburgh PiratesCincinnati RedsSt. Louis Car...  5483878  11521
#
# ...

# %%
plt.bar(team_sum['name'],team_sum['W'])
# Out:
# <BarContainer object of 139 artists>
